# %%
import urllib
link = "https://www.lawinsider.com/contracts/5jgBlCB6kT6q8wDwgd3D1f"
f = urllib.request.urlopen(link)
myfile = f.read()
print(myfile)
# Out:
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <title>Master Lease Agreement by ARC Group, Inc.</title>\n    <meta name="description" content="Master Lease Agreement filed by ARC Group, Inc. on September 5th, 2018">\n    <meta name="keywords" content="">\n    <meta name="msvalidate.01" content="60365486D867F4447F7BA0103B945BC7" />\n    <meta name="msvalidate.01" content="D88382DC32D5CE0D33E22CE753CFA524" />\n    <!-- Color the status bar on mobile devices -->\n    <meta name="theme-color" content="#0d4a86">\n    <meta name="msapplication-navbutton-color" content="#0d4a86">\n    <meta name="apple-mobile-web-app-status-bar-style" content="#0d4a86">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <!-- Disable tap highlight on IE -->\n    <meta name="msapplication-tap-highlight" content="no">\n    <!-- Web Application Manifest -->\n    <link rel="manifest" href="/manifest.json">\n    <!-- Add to homescreen for Chrome on Android -->\n    <meta name="mobile-web-app
# ...
